# %% [markdown]
# # Lesson 1.2: Python Basics
# ## Topics Covered:
# - Syntax and Semantics
# - Variables and Data Types
# - Basic Operators (Arithmetic, Comparison, Logical)

# %% [markdown]
# ## 1. Syntax and Semantics
#
# **Question 1:** Write a Python program to print "Hello, World!".

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# **Question 2:** Write a Python program that takes a user input and prints it.

# %%
fav_F1_driver = input("Enter the name of your favorite F1 driver")

print(fav_F1_driver)
# Out:
# Max Verstappen

# %% [markdown]
# **Question 3:** Write a Python program to check if a number is positive, negative, or zero.

# %%
num1 = 14

if (num1 > 0):
    print("Positive number")
if (num1 < 0):
    print("Negative number")
if (num1 == 0):
    print("Zero")
# Out:
# Positive number

# %% [markdown]
# **Question 4:** Write a Python program to find the largest of three numbers.

# %%
driver01 = 72
driver02 = 63
driver03 = 49

if (driver01 > driver02 and driver02 > driver03):
    print("Driver1 points is highest: ", driver01)
if (driver02 > driver01 and driver02 > driver03):
    print("Driver2 points is highest: ", driver02)
if (driver03 > driver01 and driver03 > driver02):
    print("Driver3 points is highest: ", driver03)
# Out:
# Driver1 points is highest:  72

# %% [markdown]
# **Question 5:** Write a Python program to calculate the factorial of a number.

# %%
num = int(input("Enter a number"))

fact = 1

while (num>0):
   fact = fact*num
   num = num - 1

print("Factorial of a number is: ", fact)
# Out:
# Factorial of a number is:  720

# %% [markdown]
# ## 2. Variables and Data Types
#
# **Question 6:** Create variables of different data types: integer, float, string, and boolean. Print their values and types.

# %%
points = 72
points_scored_per_race = 72/5
driver_name = "Kimi Antonelli"
is_winner = True

print("Points scored by driver: ", points, type(points))
print("Average score per race: ", points_scored_per_race, type(points_scored_per_race))
print("Name of the driver: ", driver_name, type(driver_name))
print("Is the race won by him: ", is_winner, type(is_winner))
# Out:
# Points scored by driver:  72 <class 'int'>
# Average score per race:  14.4 <class 'float'>
# Name of the driver:  Kimi Antonelli <class 'str'>
# Is the race won by him:  True <class 'bool'>

# %% [markdown]
# **Question 7:** Write a Python program to swap the values of two variables.

# %%
russel = 72
kimi = 63

russel = russel + kimi
kimi = russel - kimi
russel = russel - kimi

print("Points of russel after swapping: ", russel)
print("Points of kimi after swapping: ", kimi)
# Out:
# Points of russel after swapping:  63
# Points of kimi after swapping:  72

# %% [markdown]
# **Question 8:** Write a Python program to convert Celsius to Fahrenheit.

# %%
temp = int(input("Enter a temperature in Celcius"))

fah = (temp * 1.8) + 32

print("The temperature in Fahrenheit: ", fah)
# Out:
# The temperature in Fahrenheit:  73.4

# %% [markdown]
# **Question 9:** Write a Python program to concatenate two strings.

# %%
name = "Kimi"
surname = "Antonelli"

print(name + " " + surname)
# Out:
# Kimi Antonelli

# %% [markdown]
# **Question 10:** Write a Python program to check if a variable is of a specific data type.

# %%
var = 10.9

if isinstance(var, float):
    print(f"{var} is a float")
else:
    print(f"{var} is not a float")
# Out:
# 10.9 is a float

# %% [markdown]
# ## 3. Basic Operators (Arithmetic, Comparison, Logical)
#
# **Question 11:** Write a Python program to perform arithmetic operations: addition, subtraction, multiplication, and division.

# %%
driver1 = 72
driver2 = 63     ## driver1 and driver2 are from same team
driver3 = 49

total_races = 24

races_left = 21

team_score = driver1 + driver2
print("Total team score: ", team_score)

gap_between_drivers = driver1 - driver2
print("Gap between drivers: ", gap_between_drivers)

points_left = races_left * 25
print("Points left in race to score: ", points_left)

avg_point = driver3 / (total_races-races_left)
print("Average points scored by driver 3 in each race: ", avg_point)
# Out:
# Total team score:  135
# Gap between drivers:  9
# Points left in race to score:  525
# Average points scored by driver 3 in each race:  16.333333333333332

# %% [markdown]
# **Question 12:** Write a Python program to demonstrate comparison operators: equal to, not equal to, greater than, less than.

# %%
driver1 = 72
driver2 = 63     ## driver1 and driver2 are from same team
driver3 = 49

print(driver1 == driver2)

name1 = "Russell"
name2 = "russell"
print(name1 == name2)

## Not equal to
print(name1 != name2)

print(driver1 > driver2)

print(driver1 < driver2)
# Out:
# False
# False
# True
# True
# False

# %% [markdown]
# **Question 13:** Write a Python program to demonstrate logical operators: and, or, not.

# %%
driver1_winner = True
driver2_winner = False

print(driver1_winner and driver2_winner)

print(driver1_winner or driver2_winner)

print(not driver2_winner)
# Out:
# False
# True
# True

# %% [markdown]
# **Question 14:** Write a Python program to calculate the square of a number.

# %%
points = 72

sq = points**2

print("Square of a number: ", sq)
# Out:
# Square of a number:  5184

# %% [markdown]
# **Question 15:** Write a Python program to check if a number is even or odd.

# %%
points = 72

if (points % 2 == 0):
    print("Points scored by driver is even")
else:
    print("Points scored by driver is odd")
# Out:
# Points scored by driver is even

# %% [markdown]
# **Question 16:** Write a Python program to find the sum of the first n natural numbers.

# %%
num = int(input("Enter tthe number n"))

sum = (num * (num + 1))//2

print("Sum of first n natural numbers is: ", sum)
# Out:
# Sum of first n natural numbers is:  55

# %% [markdown]
# **Question 17:** Write a Python program to check if a year is a leap year.

# %%
year = int(input("Enter the year"))

if ((year % 4 == 0 and year % 100 == 0) or year % 400 == 0):
    print(year, " year is a leap year")
else:
    print(year, " year is not a leap year")
# Out:
# 2004  year is not a leap year

# %% [markdown]
# **Question 18:** Write a Python program to reverse a string.

# %%
driver_name = input("Enter the driver name")

rev_str = driver_name[::-1]

print("Reverse string is: ", rev_str)
# Out:
# Reverse string is:  illenotnA

# %% [markdown]
# **Question 19:** Write a Python program to check if a string is a palindrome.

# %%
string = "Kimmik"

if (string == string[::-1]):
    print("String entered is palindrome")
else:
    print("String entered is palindrome")
# Out:
# String entered is palindrome

# %% [markdown]
# **Question 20:** Write a Python program to sort a list of numbers in ascending order.

# %%
points = [72, 34, 24, 10, 56]

points.sort()

print("Points sorted in ascending order is: ", points)
# Out:
# Points sorted in ascending order is:  [10, 24, 34, 56, 72]
