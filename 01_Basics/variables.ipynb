# %%
## Declaring and assigning values to variable

car_name = "Buggati Chiron"
top_speed = 490
is_supercar = True

print("Car name: ", car_name)
print("Top speed(km/h): ", top_speed)
print("Is it a supercar: ", is_supercar)
# Out:
# Car name:  Buggati Chiron
# Top speed(km/h):  490
# Is it a supercar:  True

# %%
## case sensitivity

name = "Krish"
Name = "Naik"

name == Name
# Out:
# False

# %%
## type casting of variables

age = '25'
print(type(int(age)))
# Out:
# <class 'int'>

# %%
speed = 490.03
print(type(speed))

print(float(int(speed)))
# Out:
# <class 'float'>
# 490.0

# %%
## Dyanamic typing

var = "Red Bull Racing"
print(var, type(var))

var = 456.14
print(var, type(var))
# Out:
# Red Bull Racing <class 'str'>
# 456.14 <class 'float'>

# %%
#input

laps = input("How many laps are there in the race?")
print(laps)

print(type(laps))

## converting to integer
laps = int(input("How many laps are there in the race?"))
print(laps)

print(type(laps))
# Out:
# 52
# <class 'str'>
# 54
# <class 'int'>
